# %%
import pandas as pd

# %%
df_train = pd.read_csv("train.csv", index_col=0)

# %%
df_train['mean'] = df_train.mean(axis=1).round(0)
df_train
# Out:
#                y           x1           x2           x3           x4  \
# Id
# 0     738.023171  1764.052346   400.157208   978.737984  2240.893199
# 1     400.646015   144.043571  1454.273507   761.037725   121.675016
# 2     189.900156 -2552.989816   653.618595   864.436199  -742.165020
# 3     -78.399449   154.947426   378.162520  -887.785748 -1980.796468
# 4    -547.373531 -1048.552965 -1420.017937 -1706.270191  1950.775395
# ...          ...          ...          ...          ...          ...
# 9995 -199.976500   -30.453041  1082.680684  -530.579767   602.366643
# 9996   39.584572  2520.830358  -124.883939    18.067992  -998.622811
# 9997   61.176538  -545.704959  1696.765630  -508.186053     3.620563
# 9998 -202.136489  -367.787118  -568.357801  -721.247794   198.279702
# 9999 -289.218996   428.570549  -164.999054   864.962658  -647.662456
#
#                x5           x6           x7           x8           x9  \
# Id
# ...

# %%
df_test = pd.read_csv("test.csv", index_col=0)

# %%
df_test
# Out:
#                 x1           x2           x3           x4           x5  \
# Id
# 10000  -483.797492  1288.057065  -129.878712  -198.078388  -334.487592
# 10001  -316.407305    30.830556  -313.356726  -173.259184  -327.368719
# 10002 -2448.558997  -561.988408   355.098820   634.378170  -392.450091
# 10003  -942.120025   945.373015   140.910705  1753.565841  -347.223685
# 10004  1752.366157  -597.550816  -466.491398 -1094.792276  -645.424882
# ...            ...          ...          ...          ...          ...
# 11995   -70.207810   328.849423  1006.084617   440.948562  -692.274282
# 11996 -1692.417164   968.971133  1371.423442  -144.224724   503.164492
# 11997   199.864648   261.345779  -127.986805  -298.503216  -364.240174
# 11998  -151.673157 -1425.199620  1070.922114   938.800763  1373.176372
# 11999   -97.089983   780.444250   221.081520    72.748763 -1484.861623
#
#                 x6           x7           x8           x9          x10
# Id
# ...

# %%
df_test['y'] = df_test.mean(axis=1)

# %%
import numpy as np
df_test['y'] =  df_test['y'].apply(np.floor)

# %%
df_sub = df_test[["y"]]
df_sub
# Out:
#            y
# Id
# 10000  -67.0
# 10001  451.0
# 10002 -462.0
# 10003   40.0
# 10004 -127.0
# ...      ...
# 11995  464.0
# 11996  496.0
# 11997  -36.0
# 11998 -132.0
# 11999  417.0
#
# [2000 rows x 1 columns]

# %%
df_sub.to_csv("sample1.csv")
