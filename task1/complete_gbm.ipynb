# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import RobustScaler, StandardScaler
from sklearn.feature_selection import VarianceThreshold, SelectPercentile, SelectKBest, RFECV, f_regression 
from sklearn.ensemble import IsolationForest
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import  SVR

X_test = pd.read_csv("X_test.csv")
X_train = pd.read_csv("X_train.csv")
y_train = pd.read_csv("y_train.csv")

columns = X_train.columns[1:]

# convert to np arrays
X = X_train.iloc[:,1:].to_numpy()
y = y_train.iloc[:,1:].to_numpy().reshape(-1)
X_test = X_test.iloc[:,1:].to_numpy()


x_stack = np.vstack((X,X_test))
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=18)
x_stack = imputer.fit_transform(x_stack)
X = x_stack[:1212]
X_test = x_stack[1212:]

outliers = IsolationForest(n_estimators=1200, random_state=0).fit_predict(X)
#behaviour='new', max_samples=100, random_state = 1, contamination='auto'
X = X[np.where(outliers == 1)[0]].copy()
y = y[np.where(outliers == 1)[0]].copy()

selector = VarianceThreshold()
selector.fit(X)
to_delete = np.where(selector.variances_ == 0)[0]
X = np.delete(X, to_delete, axis=1)
X_test = np.delete(X_test, to_delete, axis=1)

selector = SelectKBest(f_regression, k=95)
selector.fit(X, y)
X = selector.transform(X)
X_test = selector.transform(X_test)
indices = selector.get_support(indices=True)



params = {
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': {'l2', 'l1'},
    'num_leaves': 1000,
    'learning_rate': 0.01,
    'feature_fraction': 0.95,
    'bagging_fraction': 0.9,
    'bagging_freq': 50,
    'verbose': 0
}
#params = best

import lightgbm as lgb
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.10, random_state=0)
lgb_train = lgb.Dataset(X_train, y_train)
#lgb_train = lgb.Dataset(X, y)
lgb_eval = lgb.Dataset(X_val, y_val)
gbm = lgb.train(params,
                lgb_train,
                num_boost_round=1000,
                valid_sets=lgb_eval,
                early_stopping_rounds=1000
                )
# Out:
# /home/tvinh/.local/lib/python3.8/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002429 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's l1: 7.46391	valid_0's l2: 86.5908
# Training until validation scores don't improve for 1000 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's l1: 7.41387	valid_0's l2: 85.5974
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's l1: 7.36903	valid_0's l2: 84.6836
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's l1: 7.3259	valid_0's l2: 83.815
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's l1: 7.28372	valid_0's l2: 82.9871
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's l1: 7.23984	valid_0's l2: 82.1285
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's l1: 7.19223	valid_0's l2: 81.2177
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0's l1: 7.15634	valid_0's l2: 80.4811
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid_0's l1: 7.10973	valid_0's l2: 79.5953
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's l1: 7.07622	valid_0's l2: 78.8934
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid_0's l1: 7.03537	valid_0's l2: 78.1384
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid_0's l1: 6.99263	valid_0's l2: 77.3337
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid_0's l1: 6.95413	valid_0's l2: 76.5843
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid_0's l1: 6.91993	valid_0's l2: 75.9383
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid_0's l1: 6.88748	valid_0's l2: 75.2398
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid_0's l1: 6.84986	valid_0's l2: 74.4906
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid_0's l1: 6.81483	valid_0's l2: 73.7665
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid_0's l1: 6.77537	valid_0's l2: 73.0264
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid_0's l1: 6.74536	valid_0's l2: 72.3845
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid_0's l1: 6.71407	valid_0's l2: 71.7891
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid_0's l1: 6.68042	valid_0's l2: 71.1417
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid_0's l1: 6.6424	valid_0's l2: 70.4369
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid_0's l1: 6.61269	valid_0's l2: 69.8078
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid_0's l1: 6.5833	valid_0's l2: 69.2426
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid_0's l1: 6.55555	valid_0's l2: 68.6408
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid_0's l1: 6.5258	valid_0's l2: 68.0704
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid_0's l1: 6.49013	valid_0's l2: 67.4214
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid_0's l1: 6.46354	valid_0's l2: 66.8741
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid_0's l1: 6.43185	valid_0's l2: 66.3051
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid_0's l1: 6.401	valid_0's l2: 65.7319
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	valid_0's l1: 6.37621	valid_0's l2: 65.2252
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid_0's l1: 6.34693	valid_0's l2: 64.6862
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid_0's l1: 6.32224	valid_0's l2: 64.1951
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	valid_0's l1: 6.29401	valid_0's l2: 63.6373
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid_0's l1: 6.26785	valid_0's l2: 63.1159
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid_0's l1: 6.24274	valid_0's l2: 62.5728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [37]	valid_0's l1: 6.21801	valid_0's l2: 62.0405
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [38]	valid_0's l1: 6.19761	valid_0's l2: 61.5952
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	valid_0's l1: 6.17572	valid_0's l2: 61.1727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid_0's l1: 6.14731	valid_0's l2: 60.7173
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [41]	valid_0's l1: 6.12788	valid_0's l2: 60.2636
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [42]	valid_0's l1: 6.10737	valid_0's l2: 59.8163
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [43]	valid_0's l1: 6.08218	valid_0's l2: 59.3978
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [44]	valid_0's l1: 6.05632	valid_0's l2: 58.9752
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [45]	valid_0's l1: 6.03342	valid_0's l2: 58.5003
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [46]	valid_0's l1: 6.00643	valid_0's l2: 58.0277
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [47]	valid_0's l1: 5.98367	valid_0's l2: 57.6073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [48]	valid_0's l1: 5.95564	valid_0's l2: 57.153
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [49]	valid_0's l1: 5.93123	valid_0's l2: 56.682
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	valid_0's l1: 5.91002	valid_0's l2: 56.2575
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [51]	valid_0's l1: 5.88525	valid_0's l2: 55.8101
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [52]	valid_0's l1: 5.86097	valid_0's l2: 55.3726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [53]	valid_0's l1: 5.83475	valid_0's l2: 54.9098
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [54]	valid_0's l1: 5.81264	valid_0's l2: 54.5131
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [55]	valid_0's l1: 5.79161	valid_0's l2: 54.159
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [56]	valid_0's l1: 5.77068	valid_0's l2: 53.7944
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [57]	valid_0's l1: 5.75167	valid_0's l2: 53.4319
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [58]	valid_0's l1: 5.72726	valid_0's l2: 53.0105
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [59]	valid_0's l1: 5.71436	valid_0's l2: 52.7465
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [60]	valid_0's l1: 5.68757	valid_0's l2: 52.2993
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [61]	valid_0's l1: 5.6736	valid_0's l2: 51.9929
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [62]	valid_0's l1: 5.65576	valid_0's l2: 51.6638
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [63]	valid_0's l1: 5.64181	valid_0's l2: 51.3693
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [64]	valid_0's l1: 5.63096	valid_0's l2: 51.1551
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [65]	valid_0's l1: 5.61711	valid_0's l2: 50.8849
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [66]	valid_0's l1: 5.60075	valid_0's l2: 50.6291
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [67]	valid_0's l1: 5.58292	valid_0's l2: 50.3019
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [68]	valid_0's l1: 5.56789	valid_0's l2: 50.0611
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [69]	valid_0's l1: 5.55599	valid_0's l2: 49.83
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [70]	valid_0's l1: 5.5437	valid_0's l2: 49.5511
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [71]	valid_0's l1: 5.52682	valid_0's l2: 49.2405
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [72]	valid_0's l1: 5.51374	valid_0's l2: 49.0153
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [73]	valid_0's l1: 5.50493	valid_0's l2: 48.8066
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [74]	valid_0's l1: 5.48091	valid_0's l2: 48.4328
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [75]	valid_0's l1: 5.46637	valid_0's l2: 48.1673
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [76]	valid_0's l1: 5.45402	valid_0's l2: 47.8898
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [77]	valid_0's l1: 5.4411	valid_0's l2: 47.6036
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [78]	valid_0's l1: 5.42572	valid_0's l2: 47.3406
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [79]	valid_0's l1: 5.41374	valid_0's l2: 47.1155
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [80]	valid_0's l1: 5.40289	valid_0's l2: 46.8713
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [81]	valid_0's l1: 5.3911	valid_0's l2: 46.6233
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [82]	valid_0's l1: 5.37556	valid_0's l2: 46.3447
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [83]	valid_0's l1: 5.36036	valid_0's l2: 46.0681
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [84]	valid_0's l1: 5.34937	valid_0's l2: 45.8407
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [85]	valid_0's l1: 5.34028	valid_0's l2: 45.6393
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [86]	valid_0's l1: 5.33018	valid_0's l2: 45.4595
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [87]	valid_0's l1: 5.31548	valid_0's l2: 45.2069
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [88]	valid_0's l1: 5.30219	valid_0's l2: 44.9669
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [89]	valid_0's l1: 5.28879	valid_0's l2: 44.7505
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [90]	valid_0's l1: 5.27922	valid_0's l2: 44.5588
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [91]	valid_0's l1: 5.26406	valid_0's l2: 44.2995
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [92]	valid_0's l1: 5.24713	valid_0's l2: 44.0393
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [93]	valid_0's l1: 5.23462	valid_0's l2: 43.8066
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [94]	valid_0's l1: 5.22446	valid_0's l2: 43.603
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [95]	valid_0's l1: 5.21331	valid_0's l2: 43.3658
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [96]	valid_0's l1: 5.20223	valid_0's l2: 43.1774
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [97]	valid_0's l1: 5.18859	valid_0's l2: 42.9343
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [98]	valid_0's l1: 5.17501	valid_0's l2: 42.6976
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [99]	valid_0's l1: 5.16552	valid_0's l2: 42.5282
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	valid_0's l1: 5.15015	valid_0's l2: 42.2983
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [101]	valid_0's l1: 5.1411	valid_0's l2: 42.1238
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [102]	valid_0's l1: 5.1345	valid_0's l2: 41.9868
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [103]	valid_0's l1: 5.12483	valid_0's l2: 41.8087
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [104]	valid_0's l1: 5.11688	valid_0's l2: 41.6266
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [105]	valid_0's l1: 5.10595	valid_0's l2: 41.4351
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [106]	valid_0's l1: 5.10015	valid_0's l2: 41.3109
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [107]	valid_0's l1: 5.0891	valid_0's l2: 41.1131
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [108]	valid_0's l1: 5.07718	valid_0's l2: 40.8795
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [109]	valid_0's l1: 5.07037	valid_0's l2: 40.7452
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [110]	valid_0's l1: 5.05999	valid_0's l2: 40.5448
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [111]	valid_0's l1: 5.05076	valid_0's l2: 40.3867
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [112]	valid_0's l1: 5.0452	valid_0's l2: 40.2599
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [113]	valid_0's l1: 5.03501	valid_0's l2: 40.0531
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [114]	valid_0's l1: 5.02753	valid_0's l2: 39.9178
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [115]	valid_0's l1: 5.02374	valid_0's l2: 39.7868
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [116]	valid_0's l1: 5.0188	valid_0's l2: 39.6748
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [117]	valid_0's l1: 5.01076	valid_0's l2: 39.5484
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [118]	valid_0's l1: 5.00304	valid_0's l2: 39.4057
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [119]	valid_0's l1: 4.9976	valid_0's l2: 39.3044
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [120]	valid_0's l1: 4.99031	valid_0's l2: 39.1638
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [121]	valid_0's l1: 4.98455	valid_0's l2: 39.0676
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [122]	valid_0's l1: 4.97766	valid_0's l2: 38.9195
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [123]	valid_0's l1: 4.9725	valid_0's l2: 38.8286
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [124]	valid_0's l1: 4.96745	valid_0's l2: 38.7148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [125]	valid_0's l1: 4.96133	valid_0's l2: 38.6047
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [126]	valid_0's l1: 4.95255	valid_0's l2: 38.4591
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [127]	valid_0's l1: 4.94532	valid_0's l2: 38.3385
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [128]	valid_0's l1: 4.94146	valid_0's l2: 38.2605
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [129]	valid_0's l1: 4.93161	valid_0's l2: 38.1001
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [130]	valid_0's l1: 4.91984	valid_0's l2: 37.91
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [131]	valid_0's l1: 4.91479	valid_0's l2: 37.805
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [132]	valid_0's l1: 4.90681	valid_0's l2: 37.6985
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [133]	valid_0's l1: 4.90274	valid_0's l2: 37.6022
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [134]	valid_0's l1: 4.89576	valid_0's l2: 37.4796
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [135]	valid_0's l1: 4.88631	valid_0's l2: 37.3294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [136]	valid_0's l1: 4.88267	valid_0's l2: 37.2647
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [137]	valid_0's l1: 4.87684	valid_0's l2: 37.1707
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [138]	valid_0's l1: 4.86889	valid_0's l2: 37.0408
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [139]	valid_0's l1: 4.85958	valid_0's l2: 36.8857
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [140]	valid_0's l1: 4.85097	valid_0's l2: 36.7645
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [141]	valid_0's l1: 4.84424	valid_0's l2: 36.6659
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [142]	valid_0's l1: 4.83839	valid_0's l2: 36.5856
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [143]	valid_0's l1: 4.83138	valid_0's l2: 36.4611
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [144]	valid_0's l1: 4.82448	valid_0's l2: 36.329
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [145]	valid_0's l1: 4.81684	valid_0's l2: 36.2167
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [146]	valid_0's l1: 4.81048	valid_0's l2: 36.1334
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [147]	valid_0's l1: 4.80831	valid_0's l2: 36.051
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [148]	valid_0's l1: 4.80209	valid_0's l2: 35.9662
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [149]	valid_0's l1: 4.79468	valid_0's l2: 35.8828
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [150]	valid_0's l1: 4.78955	valid_0's l2: 35.7851
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [151]	valid_0's l1: 4.7861	valid_0's l2: 35.7151
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [152]	valid_0's l1: 4.78278	valid_0's l2: 35.6408
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [153]	valid_0's l1: 4.77711	valid_0's l2: 35.5459
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [154]	valid_0's l1: 4.77329	valid_0's l2: 35.4786
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [155]	valid_0's l1: 4.76854	valid_0's l2: 35.3919
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [156]	valid_0's l1: 4.76438	valid_0's l2: 35.3288
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [157]	valid_0's l1: 4.75966	valid_0's l2: 35.2729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [158]	valid_0's l1: 4.75337	valid_0's l2: 35.1953
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [159]	valid_0's l1: 4.74713	valid_0's l2: 35.118
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [160]	valid_0's l1: 4.74175	valid_0's l2: 35.0461
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [161]	valid_0's l1: 4.73694	valid_0's l2: 34.9765
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [162]	valid_0's l1: 4.73364	valid_0's l2: 34.9073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [163]	valid_0's l1: 4.72858	valid_0's l2: 34.8438
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [164]	valid_0's l1: 4.72464	valid_0's l2: 34.803
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [165]	valid_0's l1: 4.72084	valid_0's l2: 34.7497
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [166]	valid_0's l1: 4.71489	valid_0's l2: 34.6719
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [167]	valid_0's l1: 4.71005	valid_0's l2: 34.63
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [168]	valid_0's l1: 4.70578	valid_0's l2: 34.5787
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [169]	valid_0's l1: 4.70074	valid_0's l2: 34.523
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [170]	valid_0's l1: 4.69688	valid_0's l2: 34.467
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [171]	valid_0's l1: 4.69285	valid_0's l2: 34.4327
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [172]	valid_0's l1: 4.68953	valid_0's l2: 34.3681
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [173]	valid_0's l1: 4.68602	valid_0's l2: 34.3202
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [174]	valid_0's l1: 4.68182	valid_0's l2: 34.2702
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [175]	valid_0's l1: 4.67562	valid_0's l2: 34.1969
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [176]	valid_0's l1: 4.67057	valid_0's l2: 34.1324
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [177]	valid_0's l1: 4.66573	valid_0's l2: 34.0825
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [178]	valid_0's l1: 4.66297	valid_0's l2: 34.0389
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [179]	valid_0's l1: 4.66057	valid_0's l2: 34.0041
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [180]	valid_0's l1: 4.65619	valid_0's l2: 33.9532
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [181]	valid_0's l1: 4.65103	valid_0's l2: 33.8823
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [182]	valid_0's l1: 4.64624	valid_0's l2: 33.8349
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [183]	valid_0's l1: 4.6429	valid_0's l2: 33.7844
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [184]	valid_0's l1: 4.63887	valid_0's l2: 33.7317
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [185]	valid_0's l1: 4.63368	valid_0's l2: 33.7057
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [186]	valid_0's l1: 4.6301	valid_0's l2: 33.6721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [187]	valid_0's l1: 4.62649	valid_0's l2: 33.6261
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [188]	valid_0's l1: 4.62213	valid_0's l2: 33.5906
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [189]	valid_0's l1: 4.61898	valid_0's l2: 33.5526
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [190]	valid_0's l1: 4.61587	valid_0's l2: 33.5165
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [191]	valid_0's l1: 4.61187	valid_0's l2: 33.4747
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [192]	valid_0's l1: 4.60999	valid_0's l2: 33.4369
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [193]	valid_0's l1: 4.6065	valid_0's l2: 33.3985
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [194]	valid_0's l1: 4.60461	valid_0's l2: 33.3599
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [195]	valid_0's l1: 4.59915	valid_0's l2: 33.2805
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [196]	valid_0's l1: 4.59446	valid_0's l2: 33.2259
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [197]	valid_0's l1: 4.58821	valid_0's l2: 33.1436
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [198]	valid_0's l1: 4.58192	valid_0's l2: 33.078
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [199]	valid_0's l1: 4.57958	valid_0's l2: 33.0549
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [200]	valid_0's l1: 4.58014	valid_0's l2: 33.0531
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [201]	valid_0's l1: 4.57683	valid_0's l2: 33.0087
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [202]	valid_0's l1: 4.57284	valid_0's l2: 32.976
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [203]	valid_0's l1: 4.56948	valid_0's l2: 32.94
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [204]	valid_0's l1: 4.56317	valid_0's l2: 32.8664
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [205]	valid_0's l1: 4.55982	valid_0's l2: 32.8211
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [206]	valid_0's l1: 4.55685	valid_0's l2: 32.7717
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [207]	valid_0's l1: 4.5529	valid_0's l2: 32.7245
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [208]	valid_0's l1: 4.54951	valid_0's l2: 32.6801
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [209]	valid_0's l1: 4.5459	valid_0's l2: 32.6325
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [210]	valid_0's l1: 4.54364	valid_0's l2: 32.6034
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [211]	valid_0's l1: 4.5376	valid_0's l2: 32.5133
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [212]	valid_0's l1: 4.53482	valid_0's l2: 32.4826
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [213]	valid_0's l1: 4.53109	valid_0's l2: 32.4419
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [214]	valid_0's l1: 4.52862	valid_0's l2: 32.4076
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [215]	valid_0's l1: 4.52707	valid_0's l2: 32.3854
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [216]	valid_0's l1: 4.52286	valid_0's l2: 32.3274
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [217]	valid_0's l1: 4.52256	valid_0's l2: 32.3126
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [218]	valid_0's l1: 4.52286	valid_0's l2: 32.31
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [219]	valid_0's l1: 4.52304	valid_0's l2: 32.31
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [220]	valid_0's l1: 4.52028	valid_0's l2: 32.2805
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [221]	valid_0's l1: 4.51808	valid_0's l2: 32.275
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [222]	valid_0's l1: 4.51782	valid_0's l2: 32.27
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [223]	valid_0's l1: 4.51729	valid_0's l2: 32.2626
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [224]	valid_0's l1: 4.5168	valid_0's l2: 32.2455
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [225]	valid_0's l1: 4.51723	valid_0's l2: 32.2289
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [226]	valid_0's l1: 4.5176	valid_0's l2: 32.2231
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [227]	valid_0's l1: 4.5198	valid_0's l2: 32.2436
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [228]	valid_0's l1: 4.51657	valid_0's l2: 32.2262
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [229]	valid_0's l1: 4.51456	valid_0's l2: 32.1995
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [230]	valid_0's l1: 4.51305	valid_0's l2: 32.1717
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [231]	valid_0's l1: 4.51365	valid_0's l2: 32.1831
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [232]	valid_0's l1: 4.51416	valid_0's l2: 32.1962
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [233]	valid_0's l1: 4.51407	valid_0's l2: 32.1896
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [234]	valid_0's l1: 4.51024	valid_0's l2: 32.1651
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [235]	valid_0's l1: 4.5114	valid_0's l2: 32.1873
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [236]	valid_0's l1: 4.51165	valid_0's l2: 32.1719
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [237]	valid_0's l1: 4.50946	valid_0's l2: 32.1276
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [238]	valid_0's l1: 4.50827	valid_0's l2: 32.1263
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [239]	valid_0's l1: 4.50514	valid_0's l2: 32.0772
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [240]	valid_0's l1: 4.50408	valid_0's l2: 32.0447
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [241]	valid_0's l1: 4.50165	valid_0's l2: 32.0275
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [242]	valid_0's l1: 4.49849	valid_0's l2: 31.9794
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [243]	valid_0's l1: 4.49952	valid_0's l2: 31.9816
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [244]	valid_0's l1: 4.49529	valid_0's l2: 31.9482
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [245]	valid_0's l1: 4.49036	valid_0's l2: 31.8822
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [246]	valid_0's l1: 4.48716	valid_0's l2: 31.828
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [247]	valid_0's l1: 4.48617	valid_0's l2: 31.83
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [248]	valid_0's l1: 4.48431	valid_0's l2: 31.815
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [249]	valid_0's l1: 4.48395	valid_0's l2: 31.8124
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [250]	valid_0's l1: 4.48068	valid_0's l2: 31.7632
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [251]	valid_0's l1: 4.48022	valid_0's l2: 31.7498
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [252]	valid_0's l1: 4.47744	valid_0's l2: 31.7267
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [253]	valid_0's l1: 4.47536	valid_0's l2: 31.7006
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [254]	valid_0's l1: 4.47274	valid_0's l2: 31.6754
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [255]	valid_0's l1: 4.47071	valid_0's l2: 31.6427
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [256]	valid_0's l1: 4.46962	valid_0's l2: 31.6029
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [257]	valid_0's l1: 4.46615	valid_0's l2: 31.5733
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [258]	valid_0's l1: 4.46468	valid_0's l2: 31.5535
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [259]	valid_0's l1: 4.46076	valid_0's l2: 31.5144
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [260]	valid_0's l1: 4.4596	valid_0's l2: 31.5063
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [261]	valid_0's l1: 4.4565	valid_0's l2: 31.4617
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [262]	valid_0's l1: 4.45432	valid_0's l2: 31.4199
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [263]	valid_0's l1: 4.45236	valid_0's l2: 31.399
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [264]	valid_0's l1: 4.45125	valid_0's l2: 31.3854
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [265]	valid_0's l1: 4.44939	valid_0's l2: 31.3573
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [266]	valid_0's l1: 4.44889	valid_0's l2: 31.3367
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [267]	valid_0's l1: 4.44581	valid_0's l2: 31.2921
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [268]	valid_0's l1: 4.44504	valid_0's l2: 31.2943
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [269]	valid_0's l1: 4.44387	valid_0's l2: 31.279
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [270]	valid_0's l1: 4.44255	valid_0's l2: 31.2675
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [271]	valid_0's l1: 4.44085	valid_0's l2: 31.238
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [272]	valid_0's l1: 4.44252	valid_0's l2: 31.2591
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [273]	valid_0's l1: 4.44037	valid_0's l2: 31.2204
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [274]	valid_0's l1: 4.44002	valid_0's l2: 31.2264
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [275]	valid_0's l1: 4.4388	valid_0's l2: 31.2012
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [276]	valid_0's l1: 4.43725	valid_0's l2: 31.1935
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [277]	valid_0's l1: 4.43522	valid_0's l2: 31.168
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [278]	valid_0's l1: 4.43381	valid_0's l2: 31.164
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [279]	valid_0's l1: 4.42952	valid_0's l2: 31.1194
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [280]	valid_0's l1: 4.42613	valid_0's l2: 31.0931
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [281]	valid_0's l1: 4.42488	valid_0's l2: 31.076
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [282]	valid_0's l1: 4.42292	valid_0's l2: 31.0636
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [283]	valid_0's l1: 4.41974	valid_0's l2: 31.043
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [284]	valid_0's l1: 4.41979	valid_0's l2: 31.03
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [285]	valid_0's l1: 4.41788	valid_0's l2: 31.0042
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [286]	valid_0's l1: 4.41563	valid_0's l2: 30.99
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [287]	valid_0's l1: 4.41438	valid_0's l2: 30.9681
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [288]	valid_0's l1: 4.4143	valid_0's l2: 30.9525
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [289]	valid_0's l1: 4.41217	valid_0's l2: 30.935
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [290]	valid_0's l1: 4.41272	valid_0's l2: 30.9475
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [291]	valid_0's l1: 4.41214	valid_0's l2: 30.9355
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [292]	valid_0's l1: 4.41063	valid_0's l2: 30.9322
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [293]	valid_0's l1: 4.40811	valid_0's l2: 30.8996
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [294]	valid_0's l1: 4.40655	valid_0's l2: 30.889
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [295]	valid_0's l1: 4.40461	valid_0's l2: 30.8667
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [296]	valid_0's l1: 4.404	valid_0's l2: 30.8574
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [297]	valid_0's l1: 4.40103	valid_0's l2: 30.8295
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [298]	valid_0's l1: 4.39801	valid_0's l2: 30.789
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [299]	valid_0's l1: 4.39665	valid_0's l2: 30.7735
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [300]	valid_0's l1: 4.39529	valid_0's l2: 30.7573
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [301]	valid_0's l1: 4.3946	valid_0's l2: 30.7453
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [302]	valid_0's l1: 4.39328	valid_0's l2: 30.7301
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [303]	valid_0's l1: 4.39194	valid_0's l2: 30.7117
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [304]	valid_0's l1: 4.39035	valid_0's l2: 30.6917
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [305]	valid_0's l1: 4.39002	valid_0's l2: 30.6889
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [306]	valid_0's l1: 4.38565	valid_0's l2: 30.6552
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [307]	valid_0's l1: 4.38436	valid_0's l2: 30.6384
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [308]	valid_0's l1: 4.38186	valid_0's l2: 30.6086
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [309]	valid_0's l1: 4.38072	valid_0's l2: 30.599
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [310]	valid_0's l1: 4.37973	valid_0's l2: 30.5766
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [311]	valid_0's l1: 4.37911	valid_0's l2: 30.5721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [312]	valid_0's l1: 4.37684	valid_0's l2: 30.5433
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [313]	valid_0's l1: 4.3748	valid_0's l2: 30.5212
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [314]	valid_0's l1: 4.37453	valid_0's l2: 30.5072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [315]	valid_0's l1: 4.37557	valid_0's l2: 30.5143
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [316]	valid_0's l1: 4.37475	valid_0's l2: 30.5083
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [317]	valid_0's l1: 4.37731	valid_0's l2: 30.5425
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [318]	valid_0's l1: 4.37547	valid_0's l2: 30.5149
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [319]	valid_0's l1: 4.374	valid_0's l2: 30.5025
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [320]	valid_0's l1: 4.37386	valid_0's l2: 30.5067
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [321]	valid_0's l1: 4.37258	valid_0's l2: 30.4799
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [322]	valid_0's l1: 4.37273	valid_0's l2: 30.4772
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [323]	valid_0's l1: 4.37317	valid_0's l2: 30.4939
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [324]	valid_0's l1: 4.37159	valid_0's l2: 30.4751
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [325]	valid_0's l1: 4.37022	valid_0's l2: 30.4589
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [326]	valid_0's l1: 4.37088	valid_0's l2: 30.4798
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [327]	valid_0's l1: 4.36819	valid_0's l2: 30.4675
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [328]	valid_0's l1: 4.369	valid_0's l2: 30.4914
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [329]	valid_0's l1: 4.36703	valid_0's l2: 30.4677
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [330]	valid_0's l1: 4.36764	valid_0's l2: 30.489
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [331]	valid_0's l1: 4.36582	valid_0's l2: 30.4669
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [332]	valid_0's l1: 4.36244	valid_0's l2: 30.4244
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [333]	valid_0's l1: 4.36206	valid_0's l2: 30.4197
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [334]	valid_0's l1: 4.36009	valid_0's l2: 30.4083
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [335]	valid_0's l1: 4.35689	valid_0's l2: 30.376
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [336]	valid_0's l1: 4.35634	valid_0's l2: 30.3685
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [337]	valid_0's l1: 4.3563	valid_0's l2: 30.3719
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [338]	valid_0's l1: 4.35503	valid_0's l2: 30.3659
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [339]	valid_0's l1: 4.35093	valid_0's l2: 30.3204
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [340]	valid_0's l1: 4.35126	valid_0's l2: 30.3221
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [341]	valid_0's l1: 4.34993	valid_0's l2: 30.3043
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [342]	valid_0's l1: 4.34777	valid_0's l2: 30.2754
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [343]	valid_0's l1: 4.34738	valid_0's l2: 30.2744
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [344]	valid_0's l1: 4.34712	valid_0's l2: 30.2684
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [345]	valid_0's l1: 4.34662	valid_0's l2: 30.2664
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [346]	valid_0's l1: 4.34515	valid_0's l2: 30.2456
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [347]	valid_0's l1: 4.34423	valid_0's l2: 30.2324
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [348]	valid_0's l1: 4.34506	valid_0's l2: 30.2479
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [349]	valid_0's l1: 4.34422	valid_0's l2: 30.2356
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [350]	valid_0's l1: 4.34465	valid_0's l2: 30.2335
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [351]	valid_0's l1: 4.34348	valid_0's l2: 30.2295
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [352]	valid_0's l1: 4.3431	valid_0's l2: 30.2257
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [353]	valid_0's l1: 4.34171	valid_0's l2: 30.2083
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [354]	valid_0's l1: 4.34091	valid_0's l2: 30.2012
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [355]	valid_0's l1: 4.34036	valid_0's l2: 30.2054
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [356]	valid_0's l1: 4.34183	valid_0's l2: 30.217
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [357]	valid_0's l1: 4.34052	valid_0's l2: 30.1993
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [358]	valid_0's l1: 4.34087	valid_0's l2: 30.2031
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [359]	valid_0's l1: 4.34103	valid_0's l2: 30.2038
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [360]	valid_0's l1: 4.34064	valid_0's l2: 30.2086
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [361]	valid_0's l1: 4.34127	valid_0's l2: 30.2237
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [362]	valid_0's l1: 4.33971	valid_0's l2: 30.2087
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [363]	valid_0's l1: 4.33962	valid_0's l2: 30.2078
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [364]	valid_0's l1: 4.33909	valid_0's l2: 30.2095
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [365]	valid_0's l1: 4.3393	valid_0's l2: 30.2174
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [366]	valid_0's l1: 4.33625	valid_0's l2: 30.1826
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [367]	valid_0's l1: 4.33429	valid_0's l2: 30.1624
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [368]	valid_0's l1: 4.3327	valid_0's l2: 30.1503
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [369]	valid_0's l1: 4.33309	valid_0's l2: 30.1502
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [370]	valid_0's l1: 4.33375	valid_0's l2: 30.1549
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [371]	valid_0's l1: 4.33454	valid_0's l2: 30.1606
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [372]	valid_0's l1: 4.33275	valid_0's l2: 30.144
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [373]	valid_0's l1: 4.33249	valid_0's l2: 30.1358
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [374]	valid_0's l1: 4.33243	valid_0's l2: 30.1243
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [375]	valid_0's l1: 4.33394	valid_0's l2: 30.1399
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [376]	valid_0's l1: 4.33395	valid_0's l2: 30.129
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [377]	valid_0's l1: 4.33384	valid_0's l2: 30.1331
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [378]	valid_0's l1: 4.3327	valid_0's l2: 30.1207
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [379]	valid_0's l1: 4.33196	valid_0's l2: 30.1238
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [380]	valid_0's l1: 4.33047	valid_0's l2: 30.1087
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [873]	valid_0's l1: 4.2047	valid_0's l2: 29.0453
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [874]	valid_0's l1: 4.20523	valid_0's l2: 29.0509
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [875]	valid_0's l1: 4.20516	valid_0's l2: 29.0527
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [876]	valid_0's l1: 4.20584	valid_0's l2: 29.0593
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [877]	valid_0's l1: 4.20603	valid_0's l2: 29.0625
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [878]	valid_0's l1: 4.20663	valid_0's l2: 29.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [879]	valid_0's l1: 4.20693	valid_0's l2: 29.0753
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [880]	valid_0's l1: 4.20749	valid_0's l2: 29.084
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [881]	valid_0's l1: 4.2077	valid_0's l2: 29.0865
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [882]	valid_0's l1: 4.20856	valid_0's l2: 29.0976
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [883]	valid_0's l1: 4.20942	valid_0's l2: 29.1047
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [884]	valid_0's l1: 4.20932	valid_0's l2: 29.1051
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [885]	valid_0's l1: 4.20944	valid_0's l2: 29.1042
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [886]	valid_0's l1: 4.21039	valid_0's l2: 29.1157
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [887]	valid_0's l1: 4.21061	valid_0's l2: 29.1174
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [888]	valid_0's l1: 4.21152	valid_0's l2: 29.1255
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [889]	valid_0's l1: 4.2118	valid_0's l2: 29.1255
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [890]	valid_0's l1: 4.21198	valid_0's l2: 29.1285
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [891]	valid_0's l1: 4.21251	valid_0's l2: 29.1321
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [892]	valid_0's l1: 4.21237	valid_0's l2: 29.1315
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [893]	valid_0's l1: 4.21243	valid_0's l2: 29.134
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [894]	valid_0's l1: 4.21344	valid_0's l2: 29.1409
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [895]	valid_0's l1: 4.21357	valid_0's l2: 29.1416
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [896]	valid_0's l1: 4.21324	valid_0's l2: 29.1372
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [897]	valid_0's l1: 4.21415	valid_0's l2: 29.1452
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [898]	valid_0's l1: 4.21395	valid_0's l2: 29.1415
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [899]	valid_0's l1: 4.2142	valid_0's l2: 29.1488
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [900]	valid_0's l1: 4.21451	valid_0's l2: 29.1466
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [901]	valid_0's l1: 4.21433	valid_0's l2: 29.1431
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [902]	valid_0's l1: 4.21401	valid_0's l2: 29.1376
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [903]	valid_0's l1: 4.21416	valid_0's l2: 29.1406
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [904]	valid_0's l1: 4.21355	valid_0's l2: 29.136
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [905]	valid_0's l1: 4.21332	valid_0's l2: 29.1323
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [906]	valid_0's l1: 4.21341	valid_0's l2: 29.1346
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [907]	valid_0's l1: 4.21284	valid_0's l2: 29.1318
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [908]	valid_0's l1: 4.21205	valid_0's l2: 29.1272
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [909]	valid_0's l1: 4.21264	valid_0's l2: 29.1352
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [910]	valid_0's l1: 4.21214	valid_0's l2: 29.1314
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [911]	valid_0's l1: 4.21225	valid_0's l2: 29.1286
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [912]	valid_0's l1: 4.2126	valid_0's l2: 29.1342
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [913]	valid_0's l1: 4.21245	valid_0's l2: 29.1347
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [914]	valid_0's l1: 4.21223	valid_0's l2: 29.1303
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [915]	valid_0's l1: 4.21207	valid_0's l2: 29.1267
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [916]	valid_0's l1: 4.21182	valid_0's l2: 29.1205
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [917]	valid_0's l1: 4.21083	valid_0's l2: 29.1143
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [918]	valid_0's l1: 4.21103	valid_0's l2: 29.1137
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [919]	valid_0's l1: 4.21057	valid_0's l2: 29.1093
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [920]	valid_0's l1: 4.21014	valid_0's l2: 29.1087
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [921]	valid_0's l1: 4.21052	valid_0's l2: 29.1114
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [922]	valid_0's l1: 4.20989	valid_0's l2: 29.1065
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [923]	valid_0's l1: 4.2098	valid_0's l2: 29.1019
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [924]	valid_0's l1: 4.20941	valid_0's l2: 29.1007
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [925]	valid_0's l1: 4.20932	valid_0's l2: 29.0979
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [926]	valid_0's l1: 4.20879	valid_0's l2: 29.0901
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [927]	valid_0's l1: 4.2086	valid_0's l2: 29.087
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [928]	valid_0's l1: 4.20812	valid_0's l2: 29.0823
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [929]	valid_0's l1: 4.20744	valid_0's l2: 29.0744
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [930]	valid_0's l1: 4.2065	valid_0's l2: 29.0673
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [931]	valid_0's l1: 4.20659	valid_0's l2: 29.0654
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [932]	valid_0's l1: 4.20676	valid_0's l2: 29.0671
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [933]	valid_0's l1: 4.20634	valid_0's l2: 29.0649
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [934]	valid_0's l1: 4.20656	valid_0's l2: 29.0678
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [935]	valid_0's l1: 4.20577	valid_0's l2: 29.0583
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [936]	valid_0's l1: 4.20516	valid_0's l2: 29.0499
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [937]	valid_0's l1: 4.20475	valid_0's l2: 29.0515
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [938]	valid_0's l1: 4.20508	valid_0's l2: 29.0548
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [939]	valid_0's l1: 4.20556	valid_0's l2: 29.0629
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [940]	valid_0's l1: 4.20512	valid_0's l2: 29.0597
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [941]	valid_0's l1: 4.20444	valid_0's l2: 29.0554
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [942]	valid_0's l1: 4.20383	valid_0's l2: 29.049
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [943]	valid_0's l1: 4.20432	valid_0's l2: 29.0586
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [944]	valid_0's l1: 4.20401	valid_0's l2: 29.0504
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [945]	valid_0's l1: 4.20323	valid_0's l2: 29.0425
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [946]	valid_0's l1: 4.20238	valid_0's l2: 29.0366
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [947]	valid_0's l1: 4.20219	valid_0's l2: 29.0301
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [948]	valid_0's l1: 4.20187	valid_0's l2: 29.0299
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [949]	valid_0's l1: 4.2011	valid_0's l2: 29.0247
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [950]	valid_0's l1: 4.20065	valid_0's l2: 29.0156
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [951]	valid_0's l1: 4.20042	valid_0's l2: 29.0104
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [952]	valid_0's l1: 4.2001	valid_0's l2: 29.0045
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [953]	valid_0's l1: 4.2004	valid_0's l2: 29.0033
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [954]	valid_0's l1: 4.20026	valid_0's l2: 28.9992
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [955]	valid_0's l1: 4.2006	valid_0's l2: 28.9988
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [956]	valid_0's l1: 4.20022	valid_0's l2: 28.9929
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [957]	valid_0's l1: 4.19977	valid_0's l2: 28.9878
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [958]	valid_0's l1: 4.19992	valid_0's l2: 28.9872
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [959]	valid_0's l1: 4.19981	valid_0's l2: 28.9866
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [960]	valid_0's l1: 4.20001	valid_0's l2: 28.9879
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [961]	valid_0's l1: 4.19969	valid_0's l2: 28.9776
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [962]	valid_0's l1: 4.19954	valid_0's l2: 28.9749
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [963]	valid_0's l1: 4.19946	valid_0's l2: 28.9706
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [964]	valid_0's l1: 4.19874	valid_0's l2: 28.9642
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [965]	valid_0's l1: 4.19822	valid_0's l2: 28.9595
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [966]	valid_0's l1: 4.19687	valid_0's l2: 28.9454
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [967]	valid_0's l1: 4.19638	valid_0's l2: 28.9378
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [968]	valid_0's l1: 4.19604	valid_0's l2: 28.9331
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [969]	valid_0's l1: 4.19536	valid_0's l2: 28.9223
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [970]	valid_0's l1: 4.19497	valid_0's l2: 28.9159
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [971]	valid_0's l1: 4.19425	valid_0's l2: 28.9035
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [972]	valid_0's l1: 4.19428	valid_0's l2: 28.904
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [973]	valid_0's l1: 4.19364	valid_0's l2: 28.8948
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [974]	valid_0's l1: 4.19285	valid_0's l2: 28.8831
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [975]	valid_0's l1: 4.19244	valid_0's l2: 28.8774
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [976]	valid_0's l1: 4.19165	valid_0's l2: 28.8655
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [977]	valid_0's l1: 4.19078	valid_0's l2: 28.8604
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [978]	valid_0's l1: 4.19037	valid_0's l2: 28.8542
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [979]	valid_0's l1: 4.18982	valid_0's l2: 28.8492
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [980]	valid_0's l1: 4.18913	valid_0's l2: 28.8394
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [981]	valid_0's l1: 4.18832	valid_0's l2: 28.8294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [982]	valid_0's l1: 4.18819	valid_0's l2: 28.8272
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [983]	valid_0's l1: 4.18806	valid_0's l2: 28.8264
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [984]	valid_0's l1: 4.18709	valid_0's l2: 28.8152
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [985]	valid_0's l1: 4.18661	valid_0's l2: 28.8112
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [986]	valid_0's l1: 4.18591	valid_0's l2: 28.806
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [987]	valid_0's l1: 4.18589	valid_0's l2: 28.8045
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [988]	valid_0's l1: 4.18561	valid_0's l2: 28.8035
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [989]	valid_0's l1: 4.18519	valid_0's l2: 28.7987
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [990]	valid_0's l1: 4.18459	valid_0's l2: 28.7928
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [991]	valid_0's l1: 4.18445	valid_0's l2: 28.795
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [992]	valid_0's l1: 4.1849	valid_0's l2: 28.7977
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [993]	valid_0's l1: 4.18424	valid_0's l2: 28.7924
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [994]	valid_0's l1: 4.18396	valid_0's l2: 28.7896
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [995]	valid_0's l1: 4.18398	valid_0's l2: 28.7877
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [996]	valid_0's l1: 4.18336	valid_0's l2: 28.7763
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [997]	valid_0's l1: 4.18333	valid_0's l2: 28.7752
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [998]	valid_0's l1: 4.18309	valid_0's l2: 28.774
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [999]	valid_0's l1: 4.1825	valid_0's l2: 28.7644
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1000]	valid_0's l1: 4.18232	valid_0's l2: 28.7673
# Did not meet early stopping. Best iteration is:
# [787]	valid_0's l1: 4.1778	valid_0's l2: 28.7827

# %% [markdown]
# ## Hyperopt to tune hyperparameters ????

# %%
from sklearn.metrics import r2_score

y_val_pred = gbm.predict(X_val)
r_squared = r2_score(y_val, y_val_pred)
adjusted_r_squared = 1 - (1-r_squared)*(len(y)-1)/(len(y)-X.shape[1]-1)
print("R-squared : ", r_squared)
print("Adjusted :", adjusted_r_squared)
# Out:
# R-squared :  0.6710273546657239
# Adjusted : 0.6429479285141011

# %%
y_pred = gbm.predict(X_test)
X_test = pd.read_csv("X_test.csv")
df_ids = pd.DataFrame(X_test['id'])
df_predictions = df_ids.join(pd.DataFrame(y_pred, columns=['y']))
df_predictions.to_csv('model_results/gbm_y_test.csv', index=False)

# %%
y_pred = gbm.predict(X)
X = pd.read_csv("X_train.csv")
df_ids = pd.DataFrame(X['id'])
df_predictions = df_ids.join(pd.DataFrame(y_pred, columns=['y']))
df_predictions.to_csv('model_results/gbm_y_train.csv', index=False)

# %%
from hyperopt import hp, tpe, Trials
from hyperopt.fmin import fmin
import lightgbm as lgb
import hyperopt
import lightgbm
import warnings
warnings.simplefilter("ignore")


random_state=42
n_iter = 1000

# trials will contain logging information

best_dict= {}
trials = Trials()
space = {
      'boosting_type': hp.choice('boosting_type',
                                ['gbdt','goss']),
      #dart
      'objective': hp.choice('objective',
                                ['regression','huber']),
      'learning_rate': hp.loguniform('learning_rate', np.log(0.01), np.log(0.2)),
      'colsample_bytree': hp.uniform('colsample_bytree', 0.1,0.9),
      #n_estimators': hp.quniform('n_estimators', 100, 3000, 1),
      'max_depth' : hp.quniform('max_depth', 2, 20, 1),
      'min_child_weight': hp.choice('min_child_weight', np.arange(1, 8, 1, dtype=int)),
      'subsample':        hp.uniform('subsample', 0.5, 1),
      'reg_alpha':        hp.uniform('reg_alpha', 0.001, 1),
      'reg_lambda':        hp.uniform('reg_lambda', 0.001, 1),
      'num_leaves': hp.quniform('num_leaves', 10, 5000, 1),
      'n_rows': hp.quniform('n_rows', 1000, len(X_train), 1),
      'feature_fraction': hp.uniform('feature_fraction', 0.2, 1),
  }

def gb_mse_cv(params, random_state=random_state):

    print(params)
    params['task'] = 'train'
    params['metric'] = 'l2'
    params['verbose'] = -1
    params['verbose_eval'] = -1

    n_rows = int(params.pop('n_rows'))
    #params['n_estimators'] = int(params['n_estimators'])
    params['max_depth'] = int(params['max_depth'])
    params['num_leaves'] = int(params['num_leaves'])

    train_data = lgb.Dataset(X_train[-n_rows:], label=y_train[-n_rows:],free_raw_data=False)
    valid_data = lgb.Dataset(X_test, label=y_test,free_raw_data=False)
    gbm = lgb.train(params,train_data,valid_sets=(valid_data,train_data),early_stopping_rounds=100,verbose_eval=False)
    score = gbm.best_score['valid_0']['l2']
    print(score)
    return score


best=fmin(fn=gb_mse_cv, # function to optimize
          space=space, 
          algo=tpe.suggest, # optimization algorithm, hyperotp will select its parameters automatically
          max_evals=n_iter, # maximum number of iterations
          trials=trials, # logging
          rstate=np.random.RandomState(random_state) # fixing random state for the reproducibility
        )
best['boosting_type'] = ['gbdt','goss'][best['boosting_type']]
best['objective'] = ['regression','huber'][best['objective']]
best['max_depth'] = int(best['max_depth'])
best['n_estimators'] = int(best['n_estimators'])
best['num_leaves'] = int(best['num_leaves'])
best

# %%
best

# %%
best = {'boosting_type': 'gbdt',
 'colsample_bytree': 0.5883400003755409,
 'learning_rate': 0.10708554906532587,
 'max_depth': 17,
 'min_child_weight': 4,
 'n_rows': 1045.0,
 'num_leaves': 91,
 'objective': 'regression',
 'reg_alpha': 0.03844202878778796,
 'reg_lambda': 0.10271853898205738,
 'subsample': 0.600453777629902}

# %%
'boosting_type': 'gbdt',
 'colsample_bytree': 0.489874680107508,
 'learning_rate': 0.0884474182366333,
 'max_depth': 7,
 'min_child_weight': 0,
 'n_rows': 1045.0,
 'num_leaves': 4606.0,
 'objective': 'regression',
 'reg_alpha': 0.4428519088658227,
 'reg_lambda': 0.22634346543652997,
 'subsample': 0.7789138943694276}
